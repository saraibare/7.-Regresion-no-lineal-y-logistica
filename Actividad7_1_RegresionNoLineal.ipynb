# %% [markdown]
# <a href="https://colab.research.google.com/github/saraibare/7.-Regresion-no-lineal-y-logistica/blob/main/Actividad7_1_RegresionNoLineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 7.1 (Regresión No Lineal)**
#
# Brenda Villa Campos A01732238
#
# Sara Ibarra Reyes A01734979
#
# Camila Murillo A00828860

# %%
#Cargamos librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.special as special
from scipy.optimize import curve_fit
import seaborn as sns
from sklearn.metrics import r2_score

# %%
#Cargar archivo csv
gastos2020=pd.read_csv("gastos2020_iqr.csv")
gastos2021=pd.read_csv("gastos2021_iqr.csv")
gastos2022=pd.read_csv("gastos2022_iqr.csv")
gastos2023=pd.read_csv("gastos2023_iqr.csv")

# %% [markdown]
# ## **Gastos y costos 2020**

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(gastos2020)

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
x= gastos2020[['IVA']]
y= gastos2020['TOTAL MX']

# %% [markdown]
# ### **MODELO 1: y = ax^2 + bx + c**

# %%
def  func1 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros, covs= curve_fit(func1, gastos2020['IVA'], gastos2020['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros
# Out:
# array([-1.27270708e-03,  7.85973917e+00,  1.82908100e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros, _ = curve_fit(func1, gastos2020['IVA'], gastos2020['TOTAL MX'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfit1 = a * x ** 2 + b * x + c

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#x= x.reshape(51, 1)
#y = y.reshape(51, 1)
#yfit1 = yfit1.reshape(51, 1)
yfit1
# Out:
#               IVA
# 0     1295.062535
# 1      791.288880
# 2      426.893058
# 3     1295.062535
# 4      182.908100
# ...           ...
# 3337   341.233599
# 3338  2886.106560
# 3339   388.037559
# 3340   182.908100
# 3341   182.908100
#
# [3342 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit1, label="y=a*x^2+b*x+c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
#Calculamos el coeficiente de determinación del modelo 1
R2_2020_1 = r2_score(y, yfit1) 
R2_2020_1
# Out:
# 0.7096967610349812

# %% [markdown]
# De acuerdo a la escala de correlación, el coeficiente obtenido se encuentra entre una correlación positiva considerable y una correlación positiva muy fuerte, por lo que es un buen modelo para predecir la variable IVA respecto a la variable TOTAL MX

# %%
#Corroboramos cual es el coeficiente de Correlación del modelo 1
Correl_2020_1=np.sqrt(R2_2020_1)
Correl_2020_1
# Out:
# 0.8424350188797836

# %% [markdown]
# ### **MODELO 2: y = ax^3 + bx^2 + c**

# %%
def  func2 (x, a, b, c):
     return a*x**3 + b*x**2 + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros2, covs2= curve_fit(func2, gastos2020['IVA'], gastos2020['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros2
# Out:
# array([-1.29108760e-05,  1.88150434e-02,  5.27030206e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros2, _ = curve_fit(func2, gastos2020['IVA'], gastos2020['TOTAL MX'])
a2, b2, c2 = parametros2[ 0 ], parametros2[ 1 ], parametros2[ 2 ]
yfit2 = a2 * x ** 2 + b2 * x ** 2 + c2

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#yfit2 = yfit2.reshape(51, 1)
yfit2
# Out:
#               IVA
# 0      921.799969
# 1      642.598641
# 2      545.332953
# 3      921.799969
# 4      527.030206
# ...           ...
# 3337   534.709826
# 3338  3039.773993
# 3339   539.946596
# 3340   527.030206
# 3341   527.030206
#
# [3342 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit2, label="ax^3 + bx^2 + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# En este modelo, ya que se obtiene un coeficiente de determinación negativo, se establece que la correlación es nula

# %%
#Calculamos el coeficiente de determinación del modelo 2
R2_2020_2 = r2_score(y, yfit2) 
R2_2020_2
# Out:
# -0.3476187512336466

# %%
#Calculamos el coeficiente de correlación del modelo 2
Correl_2020_2=np.sqrt(R2_2020_2)
Correl_2020_2
# Out:
# <ipython-input-95-db8c7abff180>:2: RuntimeWarning: invalid value encountered in sqrt
#   Correl_2020_2=np.sqrt(R2_2020_2)
# nan

# %% [markdown]
# ## **Gastos y costos 2021**

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(gastos2021)

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
x= gastos2021[['IVA']]
y= gastos2021['TOTAL MX']

# %% [markdown]
# ### **MODELO 1: y = ax^2 + bx + c**

# %%
def  func1 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros, covs= curve_fit(func1, gastos2021['IVA'], gastos2021['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros
# Out:
# array([-9.99521306e-04,  7.94629611e+00,  2.57749347e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros, _ = curve_fit(func1, gastos2021['IVA'], gastos2021['TOTAL MX'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfit1 = a * x ** 2 + b * x + c

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#x= x.reshape(51, 1)
#y = y.reshape(51, 1)
#yfit1 = yfit1.reshape(51, 1)
yfit1
# Out:
#               IVA
# 0      874.595345
# 1      693.339311
# 2     4336.740935
# 3     6527.251369
# 4     6527.868430
# ...           ...
# 3030   257.749347
# 3031   257.749347
# 3032  5366.892136
# 3033   257.749347
# 3034   257.749347
#
# [3035 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit1, label="y=a*x^2+b*x+c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
#Calculamos el coeficiente de determinación del modelo 1
R2_2021_1 = r2_score(y, yfit1) 
R2_2021_1
# Out:
# 0.7219070177628877

# %% [markdown]
# De acuerdo a la escala de correlación, el coeficiente obtenido se encuentra entre una correlación positiva considerable y una correlación positiva muy fuerte, por lo que es un buen modelo para predecir la variable IVA respecto a la variable TOTAL MX

# %%
#Corroboramos cual es el coeficiente de Correlación del modelo 1
Correl_2021_1=np.sqrt(R2_2021_1)
Correl_2021_1
# Out:
# 0.8496511153190395

# %% [markdown]
# ### **MODELO 2: y = ax^3 + bx^2 + c**

# %%
def  func2 (x, a, b, c):
     return a*x**3 + b*x**2 + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros2, covs2= curve_fit(func2, gastos2021['IVA'], gastos2021['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros2
# Out:
# array([-6.96865832e-06,  1.38400788e-02,  7.56483165e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros2, _ = curve_fit(func2, gastos2021['IVA'], gastos2021['TOTAL MX'])
a2, b2, c2 = parametros2[ 0 ], parametros2[ 1 ], parametros2[ 2 ]
yfit2 = a2 * x ** 2 + b2 * x ** 2 + c2

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#yfit2 = yfit2.reshape(51, 1)
yfit2
# Out:
#                IVA
# 0       841.509206
# 1       798.633205
# 2      4965.228064
# 3     11669.904712
# 4     11672.362219
# ...            ...
# 3030    756.483165
# 3031    756.483165
# 3032   7643.202105
# 3033    756.483165
# 3034    756.483165
#
# [3035 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit2, label="ax^3 + bx^2 + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# En este modelo, ya que se obtiene un coeficiente de determinación negativo, se establece que la correlación es nula

# %%
#Calculamos el coeficiente de determinación del modelo 2
R2_2021_2 = r2_score(y, yfit2) 
R2_2021_2
# Out:
# -0.5055013150015657

# %%
#Calculamos el coeficiente de correlación del modelo 2
Correl_2021_2=np.sqrt(R2_2021_2)
Correl_2021_2
# Out:
# <ipython-input-131-93e9e32fc27e>:2: RuntimeWarning: invalid value encountered in sqrt
#   Correl_2021_2=np.sqrt(R2_2021_2)
# nan

# %% [markdown]
# ## **Gastos y costos 2022**

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(gastos2022)

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
x= gastos2022[['IVA']]
y= gastos2022['TOTAL MX']

# %% [markdown]
# ### **MODELO 1: y = ax^2 + bx + c**

# %%
def  func1 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros, covs= curve_fit(func1, gastos2022['IVA'], gastos2022['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros
# Out:
# array([-2.49802789e-03,  8.46379899e+00,  4.75802111e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros, _ = curve_fit(func1, gastos2022['IVA'], gastos2022['TOTAL MX'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfit1 = a * x ** 2 + b * x + c

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#x= x.reshape(51, 1)
#y = y.reshape(51, 1)
#yfit1 = yfit1.reshape(51, 1)
yfit1
# Out:
#               IVA
# 0     1124.009674
# 1      935.392225
# 2     4384.320197
# 3     6022.736601
# 4     6023.139196
# ...           ...
# 3030   475.802111
# 3031   475.802111
# 3032  5204.063367
# 3033   475.802111
# 3034   475.802111
#
# [3035 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit1, label="y=a*x^2+b*x+c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
#Calculamos el coeficiente de determinación del modelo 1
R2_2022_1 = r2_score(y, yfit1) 
R2_2022_1
# Out:
# 0.7017631911174843

# %% [markdown]
# De acuerdo a la escala de correlación, el coeficiente obtenido se encuentra entre una correlación positiva considerable y una correlación positiva muy fuerte, por lo que es un buen modelo para predecir la variable IVA respecto a la variable TOTAL MX

# %%
#Corroboramos cual es el coeficiente de Correlación del modelo 1
Correl_2022_1=np.sqrt(R2_2022_1)
Correl_2022_1
# Out:
# 0.8377130720703148

# %% [markdown]
# ### **MODELO 2: y = ax^3 + bx^2 + c**

# %%
def  func2 (x, a, b, c):
     return a*x**3 + b*x**2 + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros2, covs2= curve_fit(func2, gastos2022['IVA'], gastos2022['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros2
# Out:
# array([-1.08022593e-05,  1.65274453e-02,  8.99689688e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros2, _ = curve_fit(func2, gastos2022['IVA'], gastos2022['TOTAL MX'])
a2, b2, c2 = parametros2[ 0 ], parametros2[ 1 ], parametros2[ 2 ]
yfit2 = a2 * x ** 2 + b2 * x ** 2 + c2

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#yfit2 = yfit2.reshape(51, 1)
yfit2
# Out:
#                IVA
# 0      1001.210225
# 1       950.016560
# 2      5924.903558
# 3     13930.243602
# 4     13933.177850
# ...            ...
# 3030    899.689688
# 3031    899.689688
# 3032   9122.387038
# 3033    899.689688
# 3034    899.689688
#
# [3035 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit2, label="ax^3 + bx^2 + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# En este modelo, ya que se obtiene un coeficiente de determinación negativo, se establece que la correlación es nula

# %%
#Calculamos el coeficiente de determinación del modelo 2
R2_2022_2 = r2_score(y, yfit2) 
R2_2022_2
# Out:
# -1.4928360785473251

# %%
#Calculamos el coeficiente de correlación del modelo 2
Correl_2022_2=np.sqrt(R2_2022_2)
Correl_2022_2
# Out:
# <ipython-input-147-3ad6870e4e8a>:2: RuntimeWarning: invalid value encountered in sqrt
#   Correl_2022_2=np.sqrt(R2_2022_2)
# nan

# %% [markdown]
# ## **Gastos y costos 2023**

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(gastos2023)

# %%
#Declaramos las variables dependientes e independientes para la regresión No lineal
x= gastos2023[['IVA']]
y= gastos2023['TOTAL MX']

# %% [markdown]
# ### **MODELO 1: y = ax^2 + bx + c**

# %%
def  func1 (x, a, b, c):
     return a*x**2 + b*x + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros, covs= curve_fit(func1, gastos2023['IVA'], gastos2023['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros
# Out:
# array([-2.95095328e-03,  8.93939826e+00,  5.29715903e+02])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros, _ = curve_fit(func1, gastos2023['IVA'], gastos2023['TOTAL MX'])
a, b, c = parametros[ 0 ], parametros[ 1 ], parametros[ 2 ]
yfit1 = a * x ** 2 + b * x + c

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#x= x.reshape(51, 1)
#y = y.reshape(51, 1)
#yfit1 = yfit1.reshape(51, 1)
yfit1
# Out:
#              IVA
# 0     529.715903
# 1     529.715903
# 2    6141.758581
# 3    6142.128272
# 4    2017.959909
# ..           ...
# 392   529.715903
# 393   529.715903
# 394  5255.791569
# 395   529.715903
# 396   529.715903
#
# [397 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit1, label="y=a*x^2+b*x+c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %%
#Calculamos el coeficiente de determinación del modelo 1
R2_2023_1 = r2_score(y, yfit1) 
R2_2023_1
# Out:
# 0.43510157172522435

# %% [markdown]
# De acuerdo a la escala de correlación, el coeficiente obtenido se encuentra entre una correlación positiva media y una correlación positiva considerable, por lo que es un modelo medianamente bueno para predecir la variable IVA respecto a la variable TOTAL MX

# %%
#Corroboramos cual es el coeficiente de Correlación del modelo 1
Correl_2023_1=np.sqrt(R2_2023_1)
Correl_2023_1
# Out:
# 0.659622294745428

# %% [markdown]
# ### **MODELO 2: y = ax^3 + bx^2 + c**

# %%
def  func2 (x, a, b, c):
     return a*x**3 + b*x**2 + c

# %%
#Ajustamos los parámetros de la función curve_fit
parametros2, covs2= curve_fit(func2, gastos2023['IVA'], gastos2023['TOTAL MX'])

# %%
#Obtenemos los coeficientes del modelo de regresión no lineal
parametros2
# Out:
# array([-1.19601835e-05,  1.76554616e-02,  1.00742673e+03])

# %%
#Creamos el modelo de predicción con los parámetros obtenidos 
parametros2, _ = curve_fit(func2, gastos2023['IVA'], gastos2023['TOTAL MX'])
a2, b2, c2 = parametros2[ 0 ], parametros2[ 1 ], parametros2[ 2 ]
yfit2 = a2 * x ** 2 + b2 * x ** 2 + c2

# %%
#Calculamos las predicciones y reestructuramos el vector de predicciones
#yfit2 = yfit2.reshape(51, 1)
yfit2
# Out:
#               IVA
# 0     1007.426734
# 1     1007.426734
# 2    14926.998429
# 3    14930.132867
# 4     1558.931536
# ..            ...
# 392   1007.426734
# 393   1007.426734
# 394   9223.471799
# 395   1007.426734
# 396   1007.426734
#
# [397 rows x 1 columns]

# %%
#Graficamos las predicciones y los datos originales para realizar la comparación
plt.plot(x, y, 'bo', label="y-original")
plt.plot(x, yfit2, label="ax^3 + bx^2 + c")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best', fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# En este modelo, ya que se obtiene un coeficiente de determinación negativo, se establece que la correlación es nula

# %%
#Calculamos el coeficiente de determinación del modelo 2
R2_2023_2 = r2_score(y, yfit2) 
R2_2023_2
# Out:
# -0.5880406865903518

# %%
#Calculamos el coeficiente de correlación del modelo 2
Correl_2023_2=np.sqrt(R2_2023_2)
Correl_2023_2
# Out:
# <ipython-input-164-9d2c57e00650>:2: RuntimeWarning: invalid value encountered in sqrt
#   Correl_2023_2=np.sqrt(R2_2023_2)
# nan

# %% [markdown]
# ## **Coeficientes de determinación**

# %%
coefdet = {'Modelo': [1,2],
           'R2_gastos2020':[R2_2020_1, R2_2020_2],
           'R2_gastos2021':[R2_2021_1, R2_2021_2],
           'R2_gastos2022':[R2_2022_1, R2_2022_2],
           'R2_gastos2023':[R2_2023_1, R2_2023_2]}
coefdet = pd.DataFrame(coefdet)
coefdet
# Out:
#    Modelo  R2_gastos2020  R2_gastos2021  R2_gastos2022  R2_gastos2023
# 0       1       0.709697       0.721907       0.459261       0.435102
# 1       2      -0.347619      -0.505501      -0.293691      -0.588041
